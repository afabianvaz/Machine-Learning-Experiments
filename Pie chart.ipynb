# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
labels = ['Chrome','Internet Explorer', 'Fire Fox', 'Edge', 'Safari', 'Sogu Explorer', 'Opera', 'Others']

# %%
marketshare = [61.74, 11.98, 11.02, 4.23, 3.79, 1.63, 1.52, 4.19]

# %%
explode= (0,0,0,0,0,0,0,0)

# %%
plt.pie(marketshare, explode = explode, labels = labels, autopct="%.1f%%", shadow=True, startangle=45)
plt.axis('equal')
plt.title('Web Browser Marketshare - 2018')
plt.show()

# %%
labels = ['Chrome','Internet Explorer', 'Fire Fox', 'Edge', 'Safari', 'Sogu Explorer', 'Opera', 'Others']

marketshare = [61.74, 11.98, 11.02, 4.23, 3.79, 1.63, 1.52, 4.19]

explode= (0,0,0.5,0,0.8,0,0,0)

plt.pie(marketshare, explode = explode, labels = labels, autopct="%.1f%%", shadow=True, startangle=45)
plt.axis('equal')
plt.title('Web Browser Marketshare - 2018')
plt.show()

# %%
labels = ['Chrome','Internet Explorer', 'Fire Fox', 'Edge', 'Safari', 'Sogu Explorer', 'Opera', 'Others']

marketshare = [61.74, 11.98, 11.02, 4.23, 3.79, 1.63, 1.52, 4.19]

explode= (0,0,0.5,0,0.8,0,0,0)

colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

plt.pie(marketshare, explode = explode, labels = labels, colors = colors, autopct="%.1f%%", shadow=True, startangle=45)
plt.axis('equal')
plt.title('Web Browser Marketshare - 2018')
plt.show()

# %%
labels = ['Chrome','Internet Explorer', 'Fire Fox', 'Edge', 'Safari', 'Sogu Explorer', 'Opera', 'Others']

marketshare = [61.74, 11.98, 11.02, 4.23, 3.79, 1.63, 1.52, 4.19]

explode= (0,0,0.5,0,0.8,0,0,0)

colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

pie = plt.pie(marketshare, explode = explode, labels = labels, colors = colors, autopct="%.1f%%", shadow=True, startangle=45)
plt.axis('equal')
plt.title('Web Browser Marketshare - 2018')
plt.legend(pie[0], labels, loc='best')
plt.show()
